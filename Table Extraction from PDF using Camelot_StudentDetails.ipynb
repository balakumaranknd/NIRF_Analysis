# %%
import camelot
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
rank_1 = camelot.read_pdf("1_IITM.pdf",pages='all')
rank_2 = camelot.read_pdf("2_IITD.pdf",pages='all')
rank_3 = camelot.read_pdf("3_IITB.pdf",pages='all')
rank_4 = camelot.read_pdf("4_IITK.pdf",pages='all')
rank_5 = camelot.read_pdf("5_IITKh.pdf",pages='all')

# %% [markdown]
# # Sanctioned_Intake

# %%
sanctioned_intake_1 = rank_1[0].df # Assigning DataFrame

# Reindexing 
sanctioned_intake_1.columns = sanctioned_intake_1.iloc[0]
sanctioned_intake_1.drop(index=0,axis=0,inplace=True)
sanctioned_intake_1.set_index(keys='Academic Year',drop=True,inplace=True)

# %%
sanctioned_intake_1.replace(to_replace='-',value=0,inplace=True) # Replace '-' with 0.

# %%
sanctioned_intake_1.drop(labels=['2014-15'],axis=1,inplace=True) # Drop column 2014-15 given all the values are 0.

# %%
sanctioned_intake_1
# Out:
# 0                       2019-20 2018-19 2017-18 2016-17 2015-16
# Academic Year
# UG [4 Years Program(s)]     762     488     466     466       0
# UG [5 Years Program(s)]     157     358     372     372     372
# PG [2 Year Program(s)]      435     403       0       0       0
# PG [3 Year Program(s)]      245     245     245       0       0

# %%
# Converting Object Data type to integer
columns = sanctioned_intake_1.columns

for i in columns:
    sanctioned_intake_1[i] = sanctioned_intake_1[i].astype('int')

# %%
sanctioned_intake_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4 entries, UG [4 Years Program(s)] to PG [3 Year Program(s)]
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   2019-20  4 non-null      int32
#  1   2018-19  4 non-null      int32
#  2   2017-18  4 non-null      int32
#  3   2016-17  4 non-null      int32
#  4   2015-16  4 non-null      int32
# dtypes: int32(5)
# memory usage: 112.0+ bytes

# %%
sanctioned_intake_2 = rank_2[0].df

#Reindexing
sanctioned_intake_2.columns = sanctioned_intake_2.iloc[0]
sanctioned_intake_2.drop(index=0,axis=0,inplace=True)
sanctioned_intake_2.set_index(keys='Academic Year',drop=True,inplace=True)
sanctioned_intake_2
# Out:
# 0                       2019-20 2018-19 2017-18 2016-17 2015-16 2014-15
# Academic Year
# UG [4 Years Program(s)]     938     798     749     749       -       -
# UG [5 Years Program(s)]     123     109     102     102     102       -
# PG [2 Year Program(s)]     1169    1045       -       -       -       -

# %%
sanctioned_intake_2.replace(to_replace='-',value=0,inplace=True) # Replace '-' with 0.

# %%
sanctioned_intake_2.drop(labels=['2014-15'],axis=1,inplace=True) # Drop column 2014-15 given all the values are 0.

# %%
sanctioned_intake_2
# Out:
# 0                       2019-20 2018-19 2017-18 2016-17 2015-16
# Academic Year
# UG [4 Years Program(s)]     938     798     749     749       0
# UG [5 Years Program(s)]     123     109     102     102     102
# PG [2 Year Program(s)]     1169    1045       0       0       0

# %%
# Converting Object Data type to integer
columns = sanctioned_intake_2.columns

for i in columns:
    sanctioned_intake_2[i] = sanctioned_intake_2[i].astype('int')

# %%
sanctioned_intake_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3 entries, UG [4 Years Program(s)] to PG [2 Year Program(s)]
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   2019-20  3 non-null      int32
#  1   2018-19  3 non-null      int32
#  2   2017-18  3 non-null      int32
#  3   2016-17  3 non-null      int32
#  4   2015-16  3 non-null      int32
# dtypes: int32(5)
# memory usage: 84.0+ bytes

# %%
sanctioned_intake_3 = rank_3[0].df
sanctioned_intake_3.columns = sanctioned_intake_3.iloc[0]
sanctioned_intake_3.drop(index=0,axis=0,inplace=True)
sanctioned_intake_3.set_index(keys='Academic Year',drop=True,inplace=True)
sanctioned_intake_3
# Out:
# 0                       2019-20 2018-19 2017-18 2016-17 2015-16 2014-15
# Academic Year
# UG [4 Years Program(s)]     773     729     729     717       -       -
# UG [5 Years Program(s)]     178     168     142     154     154       -
# PG [2 Year Program(s)]      790     753       -       -       -       -

# %%
sanctioned_intake_3.replace(to_replace='-',value=0,inplace=True) # Replace '-' with 0.

# %%
sanctioned_intake_3.drop(labels=['2014-15'],axis=1,inplace=True) # Drop column 2014-15 given all the values are 0.

# %%
sanctioned_intake_3
# Out:
# 0                       2019-20 2018-19 2017-18 2016-17 2015-16
# Academic Year
# UG [4 Years Program(s)]     773     729     729     717       0
# UG [5 Years Program(s)]     178     168     142     154     154
# PG [2 Year Program(s)]      790     753       0       0       0

# %%
# Converting Object Data type to integer
columns = sanctioned_intake_3.columns

for i in columns:
    sanctioned_intake_3[i] = sanctioned_intake_3[i].astype('int')

# %%
sanctioned_intake_3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3 entries, UG [4 Years Program(s)] to PG [2 Year Program(s)]
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   2019-20  3 non-null      int32
#  1   2018-19  3 non-null      int32
#  2   2017-18  3 non-null      int32
#  3   2016-17  3 non-null      int32
#  4   2015-16  3 non-null      int32
# dtypes: int32(5)
# memory usage: 84.0+ bytes

# %%
sanctioned_intake_4 = rank_4[0].df
sanctioned_intake_4.columns = sanctioned_intake_4.iloc[0]
sanctioned_intake_4.drop(index=0,axis=0,inplace=True)
sanctioned_intake_4.set_index(keys='Academic Year',drop=True,inplace=True)
sanctioned_intake_4
# Out:
# 0                       2019-20 2018-19 2017-18 2016-17 2015-16 2014-15
# Academic Year
# UG [4 Years Program(s)]     907     910     827     827       -       -
# PG [2 Year Program(s)]      999     896       -       -       -       -

# %%
sanctioned_intake_4.replace(to_replace='-',value=0,inplace=True) # Replace '-' with 0.

# %%
sanctioned_intake_4.drop(labels=['2014-15','2015-16'],axis=1,inplace=True) # Drop column 2014-15 & 2015-16 given all the values are 0.

# %%
sanctioned_intake_4
# Out:
# 0                       2019-20 2018-19 2017-18 2016-17
# Academic Year
# UG [4 Years Program(s)]     907     910     827     827
# PG [2 Year Program(s)]      999     896       0       0

# %%
# Converting Object Data type to integer
columns = sanctioned_intake_4.columns

for i in columns:
    sanctioned_intake_4[i] = sanctioned_intake_4[i].astype('int')

# %%
sanctioned_intake_4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2 entries, UG [4 Years Program(s)] to PG [2 Year Program(s)]
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   2019-20  2 non-null      int32
#  1   2018-19  2 non-null      int32
#  2   2017-18  2 non-null      int32
#  3   2016-17  2 non-null      int32
# dtypes: int32(4)
# memory usage: 48.0+ bytes

# %%
sanctioned_intake_5 = rank_5[0].df
sanctioned_intake_5.columns = sanctioned_intake_5.iloc[0]
sanctioned_intake_5.drop(index=0,axis=0,inplace=True)
sanctioned_intake_5.set_index(keys='Academic Year',drop=True,inplace=True)
sanctioned_intake_5
# Out:
# 0                       2019-20 2018-19 2017-18 2016-17 2015-16 2014-15
# Academic Year
# UG [4 Years Program(s)]     785     676     656     656       -       -
# PG [2 Year Program(s)]     1207    1327       -       -       -       -
# PG [3 Year Program(s)]       15      15      15       -       -       -
# PG-Integrated               756     664     645     645     645       -
# PG [6 Years Program(s)]      12       0       0       0       0       0

# %%
sanctioned_intake_5.replace(to_replace='-',value=0,inplace=True) # Replace '-' with 0.

# %%
sanctioned_intake_5.drop(labels=['2014-15','2015-16'],axis=1,inplace=True) # Drop column 2014-15 & 2015-16 given all the values are 0.

# %%
# Converting Object Data type to integer
columns = sanctioned_intake_5.columns

for i in columns:
    sanctioned_intake_5[i] = sanctioned_intake_5[i].astype('int')

# %%
sanctioned_intake_5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5 entries, UG [4 Years Program(s)] to PG [6 Years Program(s)]
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   2019-20  5 non-null      int32
#  1   2018-19  5 non-null      int32
#  2   2017-18  5 non-null      int32
#  3   2016-17  5 non-null      int32
# dtypes: int32(4)
# memory usage: 120.0+ bytes

# %%
dfs = {'1_iitm' : sanctioned_intake_1,'2_iitd' : sanctioned_intake_2,'3_iitb' : sanctioned_intake_3,
      '4_iitk' : sanctioned_intake_4,'5_iitkh' : sanctioned_intake_5}

# %%
writer = pd.ExcelWriter('SanctionedIntakes.xlsx', engine='xlsxwriter')

for sheet_name in dfs.keys():
    
    dfs[sheet_name].to_excel(writer, sheet_name=sheet_name, index=True)
    
writer.save()

# %% [markdown]
# # Student Details

# %%
student_details_1 = rank_1[1].df # Assigning DataFrame

# Reindexing 
student_details_1.columns = student_details_1.iloc[0]
student_details_1.drop(index=0,axis=0,inplace=True)
student_details_1.set_index(keys='(All programs\nof all years)',drop=True,inplace=True)

# Converting Object Data type to integer
columns = student_details_1.columns

for i in columns:
    student_details_1[i] = student_details_1[i].astype('int')

student_details_1
# Out:
# 0                             No. of Male\nStudents  No. of Female\nStudents  \
# (All programs\nof all years)
# UG [4 Years\nProgram(s)]                       1874                      332
# UG [5 Years\nProgram(s)]                       1459                      270
# PG [2 Year\nProgram(s)]                        1024                      174
# PG [3 Year\nProgram(s)]                         601                      115
#
# 0                             Total Students  \
# (All programs\nof all years)
# UG [4 Years\nProgram(s)]                2206
# UG [5 Years\nProgram(s)]                1729
# PG [2 Year\nProgram(s)]                 1198
# PG [3 Year\nProgram(s)]                  716
#
# 0                             Within State\n(Including male\n& female)  \
# (All programs\nof all years)
# UG [4 Years\nProgram(s)]                                           338
# UG [5 Years\nProgram(s)]                                           313
# ...

# %%
student_details_2 = rank_2[1].df # Assigning DataFrame

# Reindexing 
student_details_2.columns = student_details_2.iloc[0]
student_details_2.drop(index=0,axis=0,inplace=True)
student_details_2.set_index(keys='(All programs\nof all years)',drop=True,inplace=True)

# Converting Object Data type to integer
columns = student_details_2.columns

for i in columns:
    student_details_2[i] = student_details_2[i].astype('int')

student_details_2
# Out:
# 0                             No. of Male\nStudents  No. of Female\nStudents  \
# (All programs\nof all years)
# UG [4 Years\nProgram(s)]                       2957                      428
# UG [5 Years\nProgram(s)]                        512                       91
# PG [2 Year\nProgram(s)]                        1808                      369
#
# 0                             Total Students  \
# (All programs\nof all years)
# UG [4 Years\nProgram(s)]                3385
# UG [5 Years\nProgram(s)]                 603
# PG [2 Year\nProgram(s)]                 2177
#
# 0                             Within State\n(Including male\n& female)  \
# (All programs\nof all years)
# UG [4 Years\nProgram(s)]                                           252
# UG [5 Years\nProgram(s)]                                            23
# PG [2 Year\nProgram(s)]                                             67
#
# 0                             Outside State\n(Including male\n& female)  \
# ...

# %%
student_details_3 = rank_3[1].df # Assigning DataFrame

# Reindexing 
student_details_3.columns = student_details_3.iloc[0]
student_details_3.drop(index=0,axis=0,inplace=True)
student_details_3.set_index(keys='(All programs\nof all years)',drop=True,inplace=True)

# Converting Object Data type to integer
columns = student_details_3.columns

for i in columns:
    student_details_3[i] = student_details_3[i].astype('int')

student_details_3
# Out:
# 0                             No. of Male\nStudents  No. of Female\nStudents  \
# (All programs\nof all years)
# UG [4 Years\nProgram(s)]                       2874                      387
# UG [5 Years\nProgram(s)]                        790                      128
# PG [2 Year\nProgram(s)]                        1484                      254
#
# 0                             Total Students  \
# (All programs\nof all years)
# UG [4 Years\nProgram(s)]                3261
# UG [5 Years\nProgram(s)]                 918
# PG [2 Year\nProgram(s)]                 1738
#
# 0                             Within State\n(Including male\n& female)  \
# (All programs\nof all years)
# UG [4 Years\nProgram(s)]                                           852
# UG [5 Years\nProgram(s)]                                           369
# PG [2 Year\nProgram(s)]                                            419
#
# 0                             Outside State\n(Including male\n& female)  \
# ...

# %%
student_details_4 = rank_4[1].df # Assigning DataFrame

# Reindexing 
student_details_4.columns = student_details_4.iloc[0]
student_details_4.drop(index=0,axis=0,inplace=True)
student_details_4.set_index(keys='(All programs\nof all years)',drop=True,inplace=True)

# Converting Object Data type to integer
columns = student_details_4.columns

for i in columns:
    student_details_4[i] = student_details_4[i].astype('int')

student_details_4
# Out:
# 0                             No. of Male\nStudents  No. of Female\nStudents  \
# (All programs\nof all years)
# UG [4 Years\nProgram(s)]                       3100                      407
# PG [2 Year\nProgram(s)]                        1510                      249
#
# 0                             Total Students  \
# (All programs\nof all years)
# UG [4 Years\nProgram(s)]                3507
# PG [2 Year\nProgram(s)]                 1759
#
# 0                             Within State\n(Including male\n& female)  \
# (All programs\nof all years)
# UG [4 Years\nProgram(s)]                                           883
# PG [2 Year\nProgram(s)]                                            410
#
# 0                             Outside State\n(Including male\n& female)  \
# (All programs\nof all years)
# UG [4 Years\nProgram(s)]                                           2622
# PG [2 Year\nProgram(s)]                                            1341
#
# ...

# %%
student_details_5 = rank_5[1].df # Assigning DataFrame

# Reindexing 
student_details_5.columns = student_details_5.iloc[0]
student_details_5.drop(index=0,axis=0,inplace=True)
student_details_5.set_index(keys='(All programs\nof all years)',drop=True,inplace=True)

# Converting Object Data type to integer
columns = student_details_5.columns

for i in columns:
    student_details_5[i] = student_details_5[i].astype('int')

student_details_5
# Out:
# 0                             No. of Male\nStudents  No. of Female\nStudents  \
# (All programs\nof all years)
# UG [4 Years\nProgram(s)]                       2221                      298
# PG [2 Year\nProgram(s)]                        1829                      413
# PG [3 Year\nProgram(s)]                          21                        4
# PG-Integrated                                  3454                      428
# PG [6 Year\nProgram(s)]                          11                        0
#
# 0                             Total Students  \
# (All programs\nof all years)
# UG [4 Years\nProgram(s)]                2519
# PG [2 Year\nProgram(s)]                 2242
# PG [3 Year\nProgram(s)]                   25
# PG-Integrated                           3882
# PG [6 Year\nProgram(s)]                   11
#
# 0                             Within State\n(Including male\n& female)  \
# (All programs\nof all years)
# ...

# %%
dfs = {'1_iitm' : student_details_1,'2_iitd' : student_details_2,'3_iitb' : student_details_3,
      '4_iitk' : student_details_4,'5_iitkh' : student_details_5}

# %%
writer = pd.ExcelWriter('StudentDetails.xlsx', engine='xlsxwriter')

for sheet_name in dfs.keys():
    
    dfs[sheet_name].to_excel(writer, sheet_name=sheet_name, index=True)
    
writer.save()

# %% [markdown]
# # PlacementDetails_UG(4 years)

# %%
placement_4yrs_1 = rank_1[2].df # Assigning DataFrame

placement_4yrs_1.columns = placement_4yrs_1.iloc[0]
placement_4yrs_1.drop(index=0,axis=0,inplace=True)

records = [0,1,2]

for i in records:
    placement_4yrs_1.iloc[i,8] = placement_4yrs_1.iloc[i,8].split('(')[0]

int_columns = ['No. of first year\nstudents intake in the\nyear',
       'No. of first year\nstudents admitted in\nthe year',
       'No. of students\nadmitted through\nLateral entry',
       'No. of students\ngraduating in\nminimum stipulated\ntime',
       'No. of students\nplaced',
       'Median salary of\nplaced\ngraduates(Amount in\nRs.)',
       'No. of students\nselected for Higher\nStudies']

for i in int_columns:
    placement_4yrs_1[i] = placement_4yrs_1[i].astype('int')
    
placement_4yrs_1
# Out:
# 0 Academic Year  No. of first year\nstudents intake in the\nyear  \
# 1       2014-15                                              466
# 2       2015-16                                              466
# 3       2016-17                                              466
#
# 0  No. of first year\nstudents admitted in\nthe year Academic Year  \
# 1                                                441       2015-16
# 2                                                458       2016-17
# 3                                                465       2017-18
#
# 0  No. of students\nadmitted through\nLateral entry Academic Year  \
# 1                                                 0       2017-18
# 2                                                 0       2018-19
# 3                                                 0       2019-20
#
# 0  No. of students\ngraduating in\nminimum stipulated\ntime  \
# 1                                                334
# ...

# %%
placement_4yrs_1.dtypes
# Out:
# 0
# Academic Year                                               object
# No. of first year\nstudents intake in the\nyear              int32
# No. of first year\nstudents admitted in\nthe year            int32
# Academic Year                                               object
# No. of students\nadmitted through\nLateral entry             int32
# Academic Year                                               object
# No. of students\ngraduating in\nminimum stipulated\ntime     int32
# No. of students\nplaced                                      int32
# Median salary of\nplaced\ngraduates(Amount in\nRs.)          int32
# No. of students\nselected for Higher\nStudies                int32
# dtype: object

# %%
placement_4yrs_2 = rank_2[2].df # Assigning DataFrame

placement_4yrs_2.columns = placement_4yrs_2.iloc[0]
placement_4yrs_2.drop(index=0,axis=0,inplace=True)

records = [0,1,2]

for i in records:
    placement_4yrs_2.iloc[i,8] = placement_4yrs_2.iloc[i,8].split('(')[0]

int_columns = ['No. of first year\nstudents intake in the\nyear',
       'No. of first year\nstudents admitted in\nthe year',
       'No. of students\nadmitted through\nLateral entry',
       'No. of students\ngraduating in\nminimum stipulated\ntime',
       'No. of students\nplaced',
       'Median salary of\nplaced\ngraduates(Amount in\nRs.)',
       'No. of students\nselected for Higher\nStudies']

for i in int_columns:
    placement_4yrs_2[i] = placement_4yrs_2[i].astype('int')
    
placement_4yrs_2
# Out:
# 0 Academic Year  No. of first year\nstudents intake in the\nyear  \
# 1       2014-15                                              749
# 2       2015-16                                              749
# 3       2016-17                                              749
#
# 0  No. of first year\nstudents admitted in\nthe year Academic Year  \
# 1                                                759       2015-16
# 2                                                759       2016-17
# 3                                                751       2017-18
#
# 0  No. of students\nadmitted through\nLateral entry Academic Year  \
# 1                                                 0       2017-18
# 2                                                 0       2018-19
# 3                                                 0       2019-20
#
# 0  No. of students\ngraduating in\nminimum stipulated\ntime  \
# 1                                                654
# ...

# %%
placement_4yrs_2.dtypes
# Out:
# 0
# Academic Year                                               object
# No. of first year\nstudents intake in the\nyear              int32
# No. of first year\nstudents admitted in\nthe year            int32
# Academic Year                                               object
# No. of students\nadmitted through\nLateral entry             int32
# Academic Year                                               object
# No. of students\ngraduating in\nminimum stipulated\ntime     int32
# No. of students\nplaced                                      int32
# Median salary of\nplaced\ngraduates(Amount in\nRs.)          int32
# No. of students\nselected for Higher\nStudies                int32
# dtype: object

# %%
placement_4yrs_3 = rank_3[2].df # Assigning DataFrame

placement_4yrs_3.columns = placement_4yrs_3.iloc[0]
placement_4yrs_3.drop(index=0,axis=0,inplace=True)

records = [0,1,2]

for i in records:
    placement_4yrs_3.iloc[i,8] = placement_4yrs_3.iloc[i,8].split('(')[0]

int_columns = ['No. of first year\nstudents intake in the\nyear',
       'No. of first year\nstudents admitted in\nthe year',
       'No. of students\nadmitted through\nLateral entry',
       'No. of students\ngraduating in\nminimum stipulated\ntime',
       'No. of students\nplaced',
       'Median salary of\nplaced\ngraduates(Amount in\nRs.)',
       'No. of students\nselected for Higher\nStudies']

for i in int_columns:
    placement_4yrs_3[i] = placement_4yrs_3[i].astype('int')
    
placement_4yrs_3
# Out:
# 0 Academic Year  No. of first year\nstudents intake in the\nyear  \
# 1       2014-15                                              694
# 2       2015-16                                              717
# 3       2016-17                                              717
#
# 0  No. of first year\nstudents admitted in\nthe year Academic Year  \
# 1                                                682       2015-16
# 2                                                666       2016-17
# 3                                                716       2017-18
#
# 0  No. of students\nadmitted through\nLateral entry Academic Year  \
# 1                                                 0       2017-18
# 2                                                 0       2018-19
# 3                                                 0       2019-20
#
# 0  No. of students\ngraduating in\nminimum stipulated\ntime  \
# 1                                                572
# ...

# %%
placement_4yrs_3.dtypes
# Out:
# 0
# Academic Year                                               object
# No. of first year\nstudents intake in the\nyear              int32
# No. of first year\nstudents admitted in\nthe year            int32
# Academic Year                                               object
# No. of students\nadmitted through\nLateral entry             int32
# Academic Year                                               object
# No. of students\ngraduating in\nminimum stipulated\ntime     int32
# No. of students\nplaced                                      int32
# Median salary of\nplaced\ngraduates(Amount in\nRs.)          int32
# No. of students\nselected for Higher\nStudies                int32
# dtype: object

# %%
placement_4yrs_4 = rank_4[2].df # Assigning DataFrame

placement_4yrs_4.columns = placement_4yrs_4.iloc[0]
placement_4yrs_4.drop(index=0,axis=0,inplace=True)

records = [0,1,2]

for i in records:
    placement_4yrs_4.iloc[i,8] = placement_4yrs_4.iloc[i,8].split('(')[0]

int_columns = ['No. of first year\nstudents intake in the\nyear',
       'No. of first year\nstudents admitted in\nthe year',
       'No. of students\nadmitted through\nLateral entry',
       'No. of students\ngraduating in\nminimum stipulated\ntime',
       'No. of students\nplaced',
       'Median salary of\nplaced\ngraduates(Amount in\nRs.)',
       'No. of students\nselected for Higher\nStudies']

for i in int_columns:
    placement_4yrs_4[i] = placement_4yrs_4[i].astype('int')
    
placement_4yrs_4
# Out:
# 0 Academic Year  No. of first year\nstudents intake in the\nyear  \
# 1       2014-15                                              827
# 2       2015-16                                              827
# 3       2016-17                                              827
#
# 0  No. of first year\nstudents admitted in\nthe year Academic Year  \
# 1                                                809       2015-16
# 2                                                803       2016-17
# 3                                                826       2017-18
#
# 0  No. of students\nadmitted through\nLateral entry Academic Year  \
# 1                                                 0       2017-18
# 2                                                 0       2018-19
# 3                                                 0       2019-20
#
# 0  No. of students\ngraduating in\nminimum stipulated\ntime  \
# 1                                                789
# ...

# %%
placement_4yrs_4.dtypes
# Out:
# 0
# Academic Year                                               object
# No. of first year\nstudents intake in the\nyear              int32
# No. of first year\nstudents admitted in\nthe year            int32
# Academic Year                                               object
# No. of students\nadmitted through\nLateral entry             int32
# Academic Year                                               object
# No. of students\ngraduating in\nminimum stipulated\ntime     int32
# No. of students\nplaced                                      int32
# Median salary of\nplaced\ngraduates(Amount in\nRs.)          int32
# No. of students\nselected for Higher\nStudies                int32
# dtype: object

# %%
placement_4yrs_5 = rank_5[2].df # Assigning DataFrame

placement_4yrs_5.columns = placement_4yrs_5.iloc[0]
placement_4yrs_5.drop(index=0,axis=0,inplace=True)

records = [0,1,2]

for i in records:
    placement_4yrs_5.iloc[i,8] = placement_4yrs_5.iloc[i,8].split('(')[0]

int_columns = ['No. of first year\nstudents intake in the\nyear',
       'No. of first year\nstudents admitted in\nthe year',
       'No. of students\nadmitted through\nLateral entry',
       'No. of students\ngraduating in\nminimum stipulated\ntime',
       'No. of students\nplaced',
       'Median salary of\nplaced\ngraduates(Amount in\nRs.)',
       'No. of students\nselected for Higher\nStudies']

for i in int_columns:
    placement_4yrs_5[i] = placement_4yrs_5[i].astype('int')
    
placement_4yrs_5
# Out:
# 0 Academic Year  No. of first year\nstudents intake in the\nyear  \
# 1       2014-15                                              656
# 2       2015-16                                              656
# 3       2016-17                                              656
#
# 0  No. of first year\nstudents admitted in\nthe year Academic Year  \
# 1                                                641       2015-16
# 2                                                637       2016-17
# 3                                                655       2017-18
#
# 0  No. of students\nadmitted through\nLateral entry Academic Year  \
# 1                                                 0       2017-18
# 2                                                 0       2018-19
# 3                                                 0       2019-20
#
# 0  No. of students\ngraduating in\nminimum stipulated\ntime  \
# 1                                                475
# ...

# %%
placement_4yrs_5.dtypes
# Out:
# 0
# Academic Year                                               object
# No. of first year\nstudents intake in the\nyear              int32
# No. of first year\nstudents admitted in\nthe year            int32
# Academic Year                                               object
# No. of students\nadmitted through\nLateral entry             int32
# Academic Year                                               object
# No. of students\ngraduating in\nminimum stipulated\ntime     int32
# No. of students\nplaced                                      int32
# Median salary of\nplaced\ngraduates(Amount in\nRs.)          int32
# No. of students\nselected for Higher\nStudies                int32
# dtype: object

# %%
dfs = {'1_iitm' : placement_4yrs_1,'2_iitd' : placement_4yrs_2,'3_iitb' : placement_4yrs_3,
      '4_iitk' : placement_4yrs_4,'5_iitkh' : placement_4yrs_5}

# %%
writer = pd.ExcelWriter('Placement_ug4yrs.xlsx', engine='xlsxwriter')

for sheet_name in dfs.keys():
    
    dfs[sheet_name].to_excel(writer, sheet_name=sheet_name, index=True)
    
writer.save()

# %% [markdown]
# # PlacementDetails_UG(5 years)

# %%
placement_ug5yrs_1 = rank_1[3].df # Assigning DataFrame
placement_ug5yrs_1.columns = ['Academic Year','No. of first year students intake in the year','No. of first year students admitted in the year',
                                   'Academic Year','No. of students admitted through Lateral entry','Academic Year','No. of students graduating in minimum stipulated time',
                                   'No. of students placed','Median salary of placed graduates(Amount in Rs.)','No. of students selected for Higher Studies']
records = [0,1,2]

for i in records:
    placement_ug5yrs_1.iloc[i,8] = placement_ug5yrs_1.iloc[i,8].split('(')[0]

int_columns = ['No. of first year students intake in the year',
       'No. of first year students admitted in the year','No. of students admitted through Lateral entry',
       'No. of students graduating in minimum stipulated time',
       'No. of students placed',
       'Median salary of placed graduates(Amount in Rs.)',
       'No. of students selected for Higher Studies']

for col in int_columns:
    placement_ug5yrs_1[col] = placement_ug5yrs_1[col].astype('int')
    
placement_ug5yrs_1.dtypes
# Out:
# Academic Year                                            object
# No. of first year students intake in the year             int32
# No. of first year students admitted in the year           int32
# Academic Year                                            object
# No. of students admitted through Lateral entry            int32
# Academic Year                                            object
# No. of students graduating in minimum stipulated time     int32
# No. of students placed                                    int32
# Median salary of placed graduates(Amount in Rs.)          int32
# No. of students selected for Higher Studies               int32
# dtype: object

# %%
placement_ug5yrs_1
# Out:
#   Academic Year  No. of first year students intake in the year  \
# 0       2013-14                                            392
# 1       2014-15                                            392
# 2       2015-16                                            372
#
#    No. of first year students admitted in the year Academic Year  \
# 0                                              369       2014-15
# 1                                              364       2015-16
# 2                                              346       2016-17
#
#    No. of students admitted through Lateral entry Academic Year  \
# 0                                               0       2017-18
# 1                                               0       2018-19
# 2                                               0       2019-20
#
#    No. of students graduating in minimum stipulated time  \
# 0                                                341
# 1                                                314
# ...

# %%
placement_ug5yrs_2 = rank_2[3].df
placement_ug5yrs_2.columns = placement_ug5yrs_2.iloc[0]
placement_ug5yrs_2.drop(index=0,axis=0,inplace=True)

placement_ug5yrs_2.iloc[0,8] = placement_ug5yrs_2.iloc[0,8].split('(')[0]

placement_ug5yrs_2
# Out:
# 0 Academic Year No. of first year\nstudents intake in the\nyear  \
# 1       2013-14                                             180
#
# 0 No. of first year\nstudents admitted in\nthe year Academic Year  \
# 1                                               173       2014-15
#
# 0 No. of students\nadmitted through\nLateral entry Academic Year  \
# 1                                                0       2017-18
#
# 0 No. of students\ngraduating in\nminimum stipulated\ntime  \
# 1                                                145
#
# 0 No. of students\nplaced Median salary of\nplaced\ngraduates(Amount in\nRs.)  \
# 1                     109                                            1500000
#
# 0 No. of students\nselected for Higher\nStudies
# 1                                            15

# %%
placement_ug5yrs_2.columns
# Out:
# Index(['Academic Year', 'No. of first year\nstudents intake in the\nyear',
#        'No. of first year\nstudents admitted in\nthe year', 'Academic Year',
#        'No. of students\nadmitted through\nLateral entry', 'Academic Year',
#        'No. of students\ngraduating in\nminimum stipulated\ntime',
#        'No. of students\nplaced',
#        'Median salary of\nplaced\ngraduates(Amount in\nRs.)',
#        'No. of students\nselected for Higher\nStudies'],
#       dtype='object', name=0)

# %%
int_columns = [ 'No. of first year\nstudents intake in the\nyear',
       'No. of first year\nstudents admitted in\nthe year', 
       'No. of students\nadmitted through\nLateral entry',
       'No. of students\ngraduating in\nminimum stipulated\ntime',
       'No. of students\nplaced',
       'Median salary of\nplaced\ngraduates(Amount in\nRs.)',
       'No. of students\nselected for Higher\nStudies']

for col in int_columns:
    placement_ug5yrs_2[col] = placement_ug5yrs_2[col].astype('int') 
    
placement_ug5yrs_2.dtypes
# Out:
# 0
# Academic Year                                               object
# No. of first year\nstudents intake in the\nyear              int32
# No. of first year\nstudents admitted in\nthe year            int32
# Academic Year                                               object
# No. of students\nadmitted through\nLateral entry             int32
# Academic Year                                               object
# No. of students\ngraduating in\nminimum stipulated\ntime     int32
# No. of students\nplaced                                      int32
# Median salary of\nplaced\ngraduates(Amount in\nRs.)          int32
# No. of students\nselected for Higher\nStudies                int32
# dtype: object

# %%
placement_ug5yrs_3 = rank_3[3].df

placement_ug5yrs_3.columns = ['Academic Year','No. of first year students intake in the year','No. of first year students admitted in the year',
                                   'Academic Year','No. of students admitted through Lateral entry','Academic Year','No. of students graduating in minimum stipulated time',
                                   'No. of students placed','Median salary of placed graduates(Amount in Rs.)','No. of students selected for Higher Studies']
records = [0,1,2]

for i in records:
    placement_ug5yrs_3.iloc[i,8] = placement_ug5yrs_3.iloc[i,8].split('(')[0]

int_columns = ['No. of first year students intake in the year',
       'No. of first year students admitted in the year','No. of students admitted through Lateral entry',
       'No. of students graduating in minimum stipulated time',
       'No. of students placed',
       'Median salary of placed graduates(Amount in Rs.)',
       'No. of students selected for Higher Studies']

for col in int_columns:
    placement_ug5yrs_3[col] = placement_ug5yrs_3[col].astype('int')
    
placement_ug5yrs_3
# Out:
#   Academic Year  No. of first year students intake in the year  \
# 0       2013-14                                            177
# 1       2014-15                                            154
# 2       2015-16                                            154
#
#    No. of first year students admitted in the year Academic Year  \
# 0                                              173       2014-15
# 1                                              190       2015-16
# 2                                              178       2016-17
#
#    No. of students admitted through Lateral entry Academic Year  \
# 0                                               0       2017-18
# 1                                               0       2018-19
# 2                                               0       2019-20
#
#    No. of students graduating in minimum stipulated time  \
# 0                                                144
# 1                                                174
# ...

# %%
placement_ug5yrs_3.dtypes
# Out:
# Academic Year                                            object
# No. of first year students intake in the year             int32
# No. of first year students admitted in the year           int32
# Academic Year                                            object
# No. of students admitted through Lateral entry            int32
# Academic Year                                            object
# No. of students graduating in minimum stipulated time     int32
# No. of students placed                                    int32
# Median salary of placed graduates(Amount in Rs.)          int32
# No. of students selected for Higher Studies               int32
# dtype: object

# %%
dfs = {'1_iitm' : placement_ug5yrs_1,'2_iitd' : placement_ug5yrs_2,'3_iitb' : placement_ug5yrs_3}

# %%
writer = pd.ExcelWriter('Placement_ug5yrs.xlsx', engine='xlsxwriter')

for sheet_name in dfs.keys():
    
    dfs[sheet_name].to_excel(writer, sheet_name=sheet_name, index=True)
    
writer.save()

# %% [markdown]
# # Placement PG 2yrs

# %%
placement_pg2yrs_1 = rank_1[4].df

placement_pg2yrs_1.columns = placement_pg2yrs_1.iloc[0]
placement_pg2yrs_1.drop(index=0,axis=0,inplace=True)

records = [0,1,2]

for i in records:
    placement_pg2yrs_1.iloc[i,6] = placement_pg2yrs_1.iloc[i,6].split('(')[0]

int_columns = ['No. of first year\nstudents intake in the\nyear',
       'No. of first year\nstudents admitted in\nthe year',
       'No. of students graduating in minimum\nstipulated time',
       'No. of students\nplaced',
       'Median salary of\nplaced\ngraduates(Amount in\nRs.)',
       'No. of students\nselected for Higher\nStudies']

for i in int_columns:
    placement_pg2yrs_1[i] = placement_pg2yrs_1[i].astype('int')
    
placement_pg2yrs_1
# Out:
# 0 Academic Year  No. of first year\nstudents intake in the\nyear  \
# 1       2016-17                                              382
# 2       2017-18                                              429
# 3       2018-19                                              403
#
# 0  No. of first year\nstudents admitted in\nthe year Academic Year  \
# 1                                                456       2017-18
# 2                                                485       2018-19
# 3                                                411       2019-20
#
# 0  No. of students graduating in minimum\nstipulated time  \
# 1                                                320
# 2                                                459
# 3                                                302
#
# 0  No. of students\nplaced  \
# 1                      289
# 2                      373
# 3                      213
#
# 0  Median salary of\nplaced\ngraduates(Amount in\nRs.)  \
# ...

# %%
placement_pg2yrs_2 = rank_2[5].df

placement_pg2yrs_2.columns = placement_pg2yrs_2.iloc[0]
placement_pg2yrs_2.drop(index=0,axis=0,inplace=True)

records = [0,1,2]

for i in records:
    placement_pg2yrs_2.iloc[i,6] = placement_pg2yrs_2.iloc[i,6].split('(')[0]

int_columns = ['No. of first year\nstudents intake in the\nyear',
       'No. of first year\nstudents admitted in\nthe year',
       'No. of students graduating in minimum\nstipulated time',
       'No. of students\nplaced',
       'Median salary of\nplaced\ngraduates(Amount in\nRs.)',
       'No. of students\nselected for Higher\nStudies']

for i in int_columns:
    placement_pg2yrs_2[i] = placement_pg2yrs_2[i].astype('int')
    
placement_pg2yrs_2
# Out:
# 0 Academic Year  No. of first year\nstudents intake in the\nyear  \
# 1       2016-17                                             1035
# 2       2017-18                                             1252
# 3       2018-19                                             1045
#
# 0  No. of first year\nstudents admitted in\nthe year Academic Year  \
# 1                                                970       2017-18
# 2                                                996       2018-19
# 3                                                947       2019-20
#
# 0  No. of students graduating in minimum\nstipulated time  \
# 1                                                649
# 2                                                635
# 3                                                653
#
# 0  No. of students\nplaced  \
# 1                      219
# 2                      243
# 3                      322
#
# 0  Median salary of\nplaced\ngraduates(Amount in\nRs.)  \
# ...

# %%
placement_pg2yrs_2.dtypes
# Out:
# 0
# Academic Year                                             object
# No. of first year\nstudents intake in the\nyear            int32
# No. of first year\nstudents admitted in\nthe year          int32
# Academic Year                                             object
# No. of students graduating in minimum\nstipulated time     int32
# No. of students\nplaced                                    int32
# Median salary of\nplaced\ngraduates(Amount in\nRs.)        int32
# No. of students\nselected for Higher\nStudies              int32
# dtype: object

# %%
placement_pg2yrs_3 = rank_3[4].df

placement_pg2yrs_3.columns = placement_pg2yrs_3.iloc[0]
placement_pg2yrs_3.drop(index=0,axis=0,inplace=True)

records = [0,1,2]

for i in records:
    placement_pg2yrs_3.iloc[i,6] = placement_pg2yrs_3.iloc[i,6].split('(')[0]

int_columns = ['No. of first year\nstudents intake in the\nyear',
       'No. of first year\nstudents admitted in\nthe year',
       'No. of students graduating in minimum\nstipulated time',
       'No. of students\nplaced',
       'Median salary of\nplaced\ngraduates(Amount in\nRs.)',
       'No. of students\nselected for Higher\nStudies']

for i in int_columns:
    placement_pg2yrs_3[i] = placement_pg2yrs_3[i].astype('int')
    
placement_pg2yrs_3
# Out:
# 0 Academic Year  No. of first year\nstudents intake in the\nyear  \
# 1       2016-17                                              753
# 2       2017-18                                              753
# 3       2018-19                                              753
#
# 0  No. of first year\nstudents admitted in\nthe year Academic Year  \
# 1                                                798       2017-18
# 2                                                816       2018-19
# 3                                                851       2019-20
#
# 0  No. of students graduating in minimum\nstipulated time  \
# 1                                                499
# 2                                                456
# 3                                                505
#
# 0  No. of students\nplaced  \
# 1                      376
# 2                      369
# 3                      343
#
# 0  Median salary of\nplaced\ngraduates(Amount in\nRs.)  \
# ...

# %%
placement_pg2yrs_3.dtypes
# Out:
# 0
# Academic Year                                             object
# No. of first year\nstudents intake in the\nyear            int32
# No. of first year\nstudents admitted in\nthe year          int32
# Academic Year                                             object
# No. of students graduating in minimum\nstipulated time     int32
# No. of students\nplaced                                    int32
# Median salary of\nplaced\ngraduates(Amount in\nRs.)        int32
# No. of students\nselected for Higher\nStudies              int32
# dtype: object

# %%
placement_pg2yrs_4 = rank_4[3].df

placement_pg2yrs_4.columns = placement_pg2yrs_4.iloc[0]
placement_pg2yrs_4.drop(index=0,axis=0,inplace=True)

records = [0,1]

for i in records:
    placement_pg2yrs_4.iloc[i,6] = placement_pg2yrs_4.iloc[i,6].split('(')[0]

int_columns = ['No. of first year\nstudents intake in the\nyear',
       'No. of first year\nstudents admitted in\nthe year',
       'No. of students graduating in minimum\nstipulated time',
       'No. of students\nplaced',
       'Median salary of\nplaced\ngraduates(Amount in\nRs.)',
       'No. of students\nselected for Higher\nStudies']

for i in int_columns:
    placement_pg2yrs_4[i] = placement_pg2yrs_4[i].astype('int')
    
placement_pg2yrs_4
# Out:
# 0 Academic Year  No. of first year\nstudents intake in the\nyear  \
# 1       2016-17                                              895
# 2       2017-18                                              830
#
# 0  No. of first year\nstudents admitted in\nthe year Academic Year  \
# 1                                                895       2017-18
# 2                                                830       2018-19
#
# 0  No. of students graduating in minimum\nstipulated time  \
# 1                                                730
# 2                                                704
#
# 0  No. of students\nplaced  \
# 1                      449
# 2                      484
#
# 0  Median salary of\nplaced\ngraduates(Amount in\nRs.)  \
# 1                                            1075000
# 2                                            1258000
#
# 0  No. of students\nselected for Higher\nStudies
# 1                                            225
# ...

# %%
placement_pg2yrs_4.dtypes
# Out:
# 0
# Academic Year                                             object
# No. of first year\nstudents intake in the\nyear            int32
# No. of first year\nstudents admitted in\nthe year          int32
# Academic Year                                             object
# No. of students graduating in minimum\nstipulated time     int32
# No. of students\nplaced                                    int32
# Median salary of\nplaced\ngraduates(Amount in\nRs.)        int32
# No. of students\nselected for Higher\nStudies              int32
# dtype: object

# %%
placement_pg2yrs_5 = rank_5[3].df
placement_pg2yrs_5.columns = placement_pg2yrs_5.iloc[0]
placement_pg2yrs_5.drop(index=0,axis=0,inplace=True)

records = [0,1,2]

for i in records:
    placement_pg2yrs_5.iloc[i,6] = placement_pg2yrs_5.iloc[i,6].split('(')[0]

int_columns = ['No. of first year\nstudents intake in the\nyear',
       'No. of first year\nstudents admitted in\nthe year',
       'No. of students graduating in minimum\nstipulated time',
       'No. of students\nplaced',
       'Median salary of\nplaced\ngraduates(Amount in\nRs.)',
       'No. of students\nselected for Higher\nStudies']

for i in int_columns:
    placement_pg2yrs_5[i] = placement_pg2yrs_5[i].astype('int')
    
placement_pg2yrs_5
# Out:
# 0 Academic Year  No. of first year\nstudents intake in the\nyear  \
# 1       2016-17                                             1288
# 2       2017-18                                             1288
# 3       2018-19                                             1327
#
# 0  No. of first year\nstudents admitted in\nthe year Academic Year  \
# 1                                               1118       2017-18
# 2                                               1064       2018-19
# 3                                               1212       2019-20
#
# 0  No. of students graduating in minimum\nstipulated time  \
# 1                                                826
# 2                                                880
# 3                                                814
#
# 0  No. of students\nplaced  \
# 1                      418
# 2                      372
# 3                      235
#
# 0  Median salary of\nplaced\ngraduates(Amount in\nRs.)  \
# ...

# %%
placement_pg2yrs_5.dtypes
# Out:
# 0
# Academic Year                                             object
# No. of first year\nstudents intake in the\nyear            int32
# No. of first year\nstudents admitted in\nthe year          int32
# Academic Year                                             object
# No. of students graduating in minimum\nstipulated time     int32
# No. of students\nplaced                                    int32
# Median salary of\nplaced\ngraduates(Amount in\nRs.)        int32
# No. of students\nselected for Higher\nStudies              int32
# dtype: object

# %%
dfs = {'1_iitm' : placement_pg2yrs_1,'2_iitd' : placement_pg2yrs_2,'3_iitb' : placement_pg2yrs_3,
      '4_iitk' : placement_pg2yrs_4, '5_iitkh' : placement_pg2yrs_5}

# %%
writer = pd.ExcelWriter('Placement_pg2yrs.xlsx', engine='xlsxwriter')

for sheet_name in dfs.keys():
    
    dfs[sheet_name].to_excel(writer, sheet_name=sheet_name, index=True)
    
writer.save()
